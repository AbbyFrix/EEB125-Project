# %%
import pandas as pd

import os
my_dir = os.path.expanduser('~/eeb125-20261/Untitled Folder 1')
os.chdir(my_dir)
print(os.getcwd())

#reading in the csv files 
IUCN_animals = pd.read_csv("IUCN_animals.csv")
GBIF_east_africa = pd.read_csv("GBIF_east_africa.csv", sep="\t")
# Out:
# /home/jovyan/eeb125-20261/Untitled Folder 1

# %%
IUCN_animals.head()
# Out:
#    assessmentId  internalTaxonId           scientificName kingdomName  \
# 0        495630            10030        Hexanchus griseus    ANIMALIA
# 1        495907            10041      Heosemys annandalii    ANIMALIA
# 2        497499        132523146         Hubbsina turneri    ANIMALIA
# 3        497550            10267  Hungerfordia pelewensis    ANIMALIA
# 4        498370            10767      Ictalurus australis    ANIMALIA
#
#   phylumName           orderName       className       familyName  \
# 0   CHORDATA      HEXANCHIFORMES  CHONDRICHTHYES      HEXANCHIDAE
# 1   CHORDATA          TESTUDINES        REPTILIA      GEOEMYDIDAE
# 2   CHORDATA  CYPRINODONTIFORMES  ACTINOPTERYGII        GOODEIDAE
# 3   MOLLUSCA   ARCHITAENIOGLOSSA      GASTROPODA  DIPLOMMATINIDAE
# 4   CHORDATA        SILURIFORMES  ACTINOPTERYGII      ICTALURIDAE
#
#       genusName speciesName  infraType  infraName  infraAuthority  \
# 0     Hexanchus     griseus        NaN        NaN             NaN
# 1      Heosemys  annandalii        NaN        NaN             NaN
# 2      Hubbsina     turneri        NaN        NaN             NaN
# 3  Hungerfordia  pelewensis        NaN        NaN             NaN
# 4     Ictalurus   australis        NaN        NaN             NaN
#
#                                        authority        redlistCategory  \
# 0                             (Bonnaterre, 1788)        Near Threatened
# 1  (Boulenger in Annandale &amp; Robinson, 1903)  Critically Endangered
# 2                                (de Buen, 1940)  Critically Endangered
# 3                                  Beddome, 1889             Endangered
# 4                                   (Meek, 1904)         Data Deficient
#
#                       redlistCriteria  criteriaVersion populationTrend  scopes
# 0                                A2bd              3.1      Decreasing  Global
# 1                            A2cd+4cd              3.1      Decreasing  Global
# 2  B1ab(i,ii,iii,iv)+2ab(i,ii,iii,iv)              3.1      Decreasing  Global
# 3            B1ab(ii,iii)+2ab(ii,iii)              3.1         Unknown  Global
# 4                                 NaN              3.1      Decreasing  Global

# %%
GBIF_east_africa.head()
# Out:
#    taxonKey                         scientificName  acceptedTaxonKey  \
# 0       341                            Turbellaria             341.0
# 1      2390                       Scrophulariaceae            2390.0
# 2      4334                                 Apidae            4334.0
# 3   1033975                 Enochrus Thomson, 1859         1033975.0
# 4   1055329  Ablaberoides emeritus Péringuey, 1904         1055329.0
#
#                   acceptedScientificName  numberOfOccurrences taxonRank  \
# 0                            Turbellaria                  297     CLASS
# 1                       Scrophulariaceae                   86    FAMILY
# 2                                 Apidae                   39    FAMILY
# 3                 Enochrus Thomson, 1859                   47     GENUS
# 4  Ablaberoides emeritus Péringuey, 1904                    6   SPECIES
#
#   taxonomicStatus   kingdom  kingdomKey           phylum  ...  classKey  \
# 0        ACCEPTED  Animalia           1  Platyhelminthes  ...     341.0
# 1        ACCEPTED   Plantae           6     Tracheophyta  ...     220.0
# 2        ACCEPTED  Animalia           1       Arthropoda  ...     216.0
# 3        ACCEPTED  Animalia           1       Arthropoda  ...     216.0
# 4        ACCEPTED  Animalia           1       Arthropoda  ...     216.0
#
#          order  orderKey            family  familyKey         genus  \
# 0          NaN       NaN               NaN        NaN           NaN
# 1     Lamiales     408.0  Scrophulariaceae     2390.0           NaN
# 2  Hymenoptera    1457.0            Apidae     4334.0           NaN
# 3   Coleoptera    1470.0     Hydrophilidae     7830.0      Enochrus
# 4   Coleoptera    1470.0     Melolonthidae     5593.0  Ablaberoides
#
#     genusKey                species  speciesKey iucnRedListCategory
# 0        NaN                    NaN         NaN                 NaN
# 1        NaN                    NaN         NaN                  NE
# 2        NaN                    NaN         NaN                  NE
# 3  1033975.0                    NaN         NaN                 NaN
# 4  1055303.0  Ablaberoides emeritus   1055329.0                  NE
#
# [5 rows x 22 columns]

# %%
#Next we want to work with cleaned dataframes and only use relevant columnns to our research questions 


IUCN_cols = ['genusName','speciesName','scientificName','redlistCategory']

GBIF_cols = ['genus', 'species','iucnRedListCategory', 'numberOfOccurrences']

IUCN_filtered = IUCN_animals[IUCN_cols]

GBIF_filtered = GBIF_east_africa[GBIF_cols]

#the scientific name columns do not match between the datasets so let's correct that 

old_to_new_IUCN = {'genusName':'Genus',
                  'speciesName':'Species',
                  'scientificName':'Scientific Name',
                  'redlistCategory':'IUCN Red List Category'}

old_to_new_GBIF = {'genus':'Genus',
                  'species':'Scientific Name',
                  'iucnRedListCategory':'IUCN Red List Abbreviation', 
                  'numberOfOccurrences': 'Number of Occurrences'}

GBIF_renamed = GBIF_filtered.rename(columns = old_to_new_GBIF)

IUCN_renamed = IUCN_filtered.rename(columns = old_to_new_IUCN)

# %%
#converting data types 

GBIF_converted = GBIF_renamed.convert_dtypes()
IUCN_converted = IUCN_renamed.convert_dtypes()

# %%
#replacing the NaN values 
GBIF_converted = GBIF_converted.replace('NaN', pd.NA)
IUCN_converted = IUCN_converted.replace('NaN',pd.NA)

# %%
#merging the GBIF and IUCN datasets 

GBIF_IUCN_combined = pd.merge(
    left = GBIF_converted, 
    right = IUCN_converted, 
    left_on = "Scientific Name", 
    right_on = "Scientific Name")

GBIF_IUCN_combined
# Out:
#              Genus_x          Scientific Name IUCN Red List Abbreviation  \
# 0           Hetrodes           Hetrodes pupus                         LC
# 1       Chrysichthys  Chrysichthys brachynema                         LC
# 2      Mastacembelus   Mastacembelus frenatus                         LC
# 3           Brycinus     Brycinus rhodopleura                         NE
# 4         Istigobius     Istigobius decoratus                         LC
# ...              ...                      ...                        ...
# 10740      Motacilla          Motacilla flava                       <NA>
# 10741       Oenanthe      Oenanthe scotocerca                       <NA>
# 10742          Conus            Conus lividus                         LC
# 10743      Crocidura     Crocidura macmillani                       <NA>
# 10744       Cacyreus          Cacyreus fracta                         LC
#
#        Number of Occurrences        Genus_y      Species  \
# 0                         13       Hetrodes        pupus
# 1                         18   Chrysichthys   brachynema
# 2                          3  Mastacembelus     frenatus
# 3                          1       Brycinus  rhodopleura
# 4                          8     Istigobius    decoratus
# ...                      ...            ...          ...
# 10740                      1      Motacilla        flava
# 10741                      4       Oenanthe   scotocerca
# 10742                     49          Conus      lividus
# 10743                      1      Crocidura   macmillani
# 10744                      2       Cacyreus       fracta
#
#       IUCN Red List Category
# 0              Least Concern
# 1              Least Concern
# 2              Least Concern
# 3              Least Concern
# 4              Least Concern
# ...                      ...
# 10740          Least Concern
# 10741          Least Concern
# 10742          Least Concern
# 10743        Near Threatened
# 10744          Least Concern
#
# [10745 rows x 7 columns]

# %%
#Now that we have combined the datasets, we can calculate the counts of unique species
#first only include the statuses of interest to us

not_DD = GBIF_IUCN_combined['IUCN Red List Abbreviation'] != 'DD'

not_NE = GBIF_IUCN_combined['IUCN Red List Abbreviation'] != 'NE'

not_EW = GBIF_IUCN_combined['IUCN Red List Abbreviation'] != 'EW'

not_EX = GBIF_IUCN_combined['IUCN Red List Abbreviation'] != 'EX'

all_conditions = not_DD & not_NE & not_EW & not_EX

combined_filtered = GBIF_IUCN_combined[all_conditions]

unique_species_count = combined_filtered.groupby('IUCN Red List Abbreviation')['Scientific Name'].nunique()

print(unique_species_count)

proportions = unique_species_count / unique_species_count.sum()
print(proportions)
# Out:
# IUCN Red List Abbreviation
# CR     138
# EN     230
# LC    5028
# NT     241
# VU     309
# Name: Scientific Name, dtype: int64
# IUCN Red List Abbreviation
# CR    0.023209
# EN    0.038681
# LC    0.845610
# NT    0.040531
# VU    0.051968
# Name: Scientific Name, dtype: float64

# %%
#Now that we have the proportions belonging to each
